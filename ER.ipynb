# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:35px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:20px;">
#
# <h1 style="
#     font-size:36px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:3px;
#     margin:0;
#     text-transform:uppercase;
#     text-shadow:
#         0 1px 0 #0a1a22,
#         0 2px 0 #091820,
#         0 3px 0 #071117,
#         0 4px 0 #050d12,
#         0 8px 15px rgba(0,0,0,0.6),
#         0 12px 25px rgba(0,0,0,0.5);
# ">
# HOSPITAL EMERGENCY ROOM LOAD ANALYSIS
# </h1>
#
# </div>

# %% [markdown]
# <div align="center" style="background-color:#0f2027; padding:20px; border-radius:10px; border:2px solid #00c6ff;">
#
# <h1 style="color:white; margin-bottom:10px;">About Author</h1>
#
# <a href="https://www.sak.kesug.com">
# <img src="https://avatars.githubusercontent.com/sohail-ahmed-26"
# width="120"
# style="border-radius:50%; border:3px solid #00c6ff;">
# </a>
#
# <h2 style="color:white; margin-top:15px;">Mr. Sohail Ahmed</h2>
#
# <p style="color:#cfd8dc;">
# <span style="color:#00e5ff;"><b>Data Scientist / ML Engineer</b></span><br>
# BS Telecommunication
# </p>
#
# <p>
# <a href="https://youtube.com/@sohailahmed-k4k?si=uZ7KjZ_0qTkNekgp">
# <img width="40" src="https://img.icons8.com/color/48/youtube-play.png">
# </a>
# <a href="https://x.com/ahmed241126">
# <img width="40" src="https://img.icons8.com/dotty/80/x.png">
# </a>
# <a href="https://www.linkedin.com/in/sohail-ahmed-devsil">
# <img width="40" src="https://img.icons8.com/color/48/linkedin.png">
# </a>
# <a href="https://github.com/sohail-ahmed-26">
# <img width="40" src="https://img.icons8.com/ios-glyphs/50/github.png">
# </a>
# <a href="https://www.kaggle.com/sohail2411126">
# <img width="40" src="https://img.icons8.com/clouds/100/kaggle.png">
# </a>
# </p>
#
# <p>
# <a href="https://www.sak.kesug.com"
# style="color:#00c6ff; text-decoration:none; border:1px solid #00c6ff; padding:6px 15px; border-radius:6px;">
# Portfolio Site
# </a>
# </p>
#
# </div>

# %% [markdown]
# <!-- MAIN HEADING -->
#
# <div align="center">
#
# <h1 style="
# color:#9feaf9;
# font-size:36px;
# font-weight:900;
# letter-spacing:4px;
# font-family:Segoe UI, sans-serif;
# margin-bottom:5px;">
# TABLE OF CONTENTS
# </h1>
#
# <h3 style="
# color:#ffffff;
# font-size:18px;
# letter-spacing:2px;
# font-family:Segoe UI, sans-serif;">
# HOSPITAL EMERGENCY ROOM LOAD ANALYSIS DASHBOARD
# </h3>
#
# </div>
#
#
# <!-- PROJECT OVERVIEW -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:15px;">
# Project Overview
# </div>
#
#
# <!-- INTRODUCTION -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Introduction
# </div>
#
#
# <!-- DATASET INFORMATION -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Dataset Information
#
# <ul style="margin-top:8px; color:#cfd8dc;">
# <li>Dataset Source</li>
# <li>Dataset Description</li>
# <li>Features Overview</li>
# </ul>
#
# </div>
#
#
# <!-- DATA IMPORT -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Data Import & Initial Data Check
#
# <ul style="margin-top:8px; color:#cfd8dc;">
# <li>Import Required Libraries</li>
# <li>Load Dataset</li>
# <li>Display First Rows</li>
# <li>Check Dataset Shape</li>
# <li>Check Data Types</li>
# <li>Dataset Summary Information</li>
# </ul>
#
# </div>
#
#
# <!-- DATA CLEANING -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Data Cleaning
#
# <ul style="margin-top:8px; color:#cfd8dc;">
# <li>Handling Missing Values</li>
# <li>Removing Duplicate Records</li>
# <li>Fixing Date & Time Format</li>
# <li>Creating Hour of Arrival</li>
# <li>Creating Day of Week</li>
# </ul>
#
# </div>
#
#
# <!-- BASIC STATISTICS -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Basic Statistics
#
# <ul style="margin-top:8px; color:#cfd8dc;">
# <li>Average Waiting Time</li>
# <li>Median Waiting Time</li>
# <li>Minimum Waiting Time</li>
# <li>Maximum Waiting Time</li>
# <li>Patient Age Distribution</li>
# </ul>
#
# </div>
#
#
# <!-- PEAK TIME ANALYSIS -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Peak Time Analysis
# </div>
#
#
# <!-- WAITING TIME ANALYSIS -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Waiting Time Analysis
# </div>
#
#
# <!-- DEMOGRAPHIC STUDY -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Demographic Study
# </div>
#
#
# <!-- DATA VISUALIZATIONS -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Data Visualizations
# </div>
#
#
# <!-- FINAL REPORT -->
#
# <div style="
# background:linear-gradient(135deg,#1b2735,#2c3e50);
# padding:14px;
# border-radius:8px;
# border-left:5px solid #00e5ff;
# color:#ffffff;
# font-weight:600;
# margin-top:10px;">
# Final Report
# </div>

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
#  PROJECT OVERVIEW
# </div>
#
# <!-- Content Box -->
#
# <div style="background:#16222a;
# padding:20px;
# border-radius:10px;
# border-left:5px solid #00aeff;
# color:#e3f2fd;
# font-size:15px;
# line-height:1.8;">
#
# <ul>
#
# <li>
# <b>Project Purpose:</b>
# This project analyzes hospital emergency room data to understand patient flow, waiting times, and workload patterns in the emergency department.
# </li>
#
# <br>
#
# <li>
# <b>Dataset Used:</b>
# The analysis is performed using an Emergency Room patient dataset that contains information about patient arrival time, waiting time, age, gender, triage level, and visit details.
# </li>
#
# <br>
#
# <li>
# <b>Core Analysis Performed:</b>
# The project includes data cleaning, exploratory data analysis (EDA), statistical analysis, peak time analysis, and visualization to identify patterns in emergency room visits.
# </li>
#
# <br>
#
# <li>
# <b>Key Variables Analyzed:</b>
# Patient waiting time, arrival hour, day of the week, age group, gender distribution, and triage level.
# </li>
#
# <br>
#
# <li>
# <b>Healthcare Impact:</b>
# The insights generated from this analysis help hospital management understand busy hours, reduce patient waiting time, and improve emergency room efficiency.
# </li>
#
# </ul>
#
# </div>
#
# </div>

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# INTRODUCTION
#
# </h1>
#
# </div>
#
#
# <!-- Content Box -->
#
# <div style="
# background: linear-gradient(135deg,#0f2027,#203a43,#2c5364);
# padding:25px;
# border-radius:12px;
# border:2px solid #00e5ff;
# margin-top:15px;
# color:#e6f7ff;
# font-size:15px;
# line-height:1.8;
# ">
#
# <p>
#
# Emergency Rooms (ER) play a critical role in hospitals by providing immediate medical care to patients with urgent health conditions. However, many hospitals experience overcrowding in their emergency departments, which can lead to long waiting times and increased pressure on medical staff.
#
# </p>
#
# <p>
#
# In this project, we analyze emergency room patient data to understand how busy the hospital ER becomes at different times. The goal is to identify patterns in patient arrivals, waiting times, and demographic characteristics.
#
# </p>
#
# <p>
#
# By studying this data, we aim to discover peak hours, busiest days, and factors that contribute to longer waiting times. These insights can help hospital administrators improve patient flow, optimize staffing, and enhance the overall efficiency of the emergency department.
#
# </p>
#
# </div>

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# DATASET INFORMATION
# </h2>
#
# </div>
#
# <!-- SUBSECTION -->
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Dataset Source
# </h3>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# The dataset used in this project is an <b style="color:#ffffff;">Emergency Room Patient Visit Dataset</b>.
# This dataset contains records of patients visiting a hospital emergency department and is used to analyze patient flow, waiting times, and workload patterns in the ER.
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# <b style="color:#ffffff;">Source Platform:</b> Kaggle / Course Dataset<br>
# <b style="color:#ffffff;">Dataset Name:</b> ER Wait Time Dataset<br>
# <b style="color:#ffffff;">Usage Purpose:</b> Emergency Room Load Analysis
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# This dataset contains patient-level information including arrival time, waiting time before treatment, patient age, gender, and triage level. These variables help analyze hospital emergency room performance, identify peak hours, and understand factors affecting patient waiting times.
# </p>
#
# </div>

# %% [markdown]
# <!-- SUBSECTION -->
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 4.2 Dataset Description
# </h3>
#
# <ul style="color:#cfd8dc; line-height:1.9; font-size:16px;">
#
# <li>
# The dataset contains records of patients who visited the hospital emergency room (ER) for medical treatment.
# Each row in the dataset represents a single patient visit.
# </li>
#
# <li>
# It includes important information related to patient arrival time, waiting time before treatment,
# and basic demographic details such as age and gender.
# </li>
#
# <li>
# The dataset allows us to study patient flow in the emergency department and understand how the workload changes during different hours of the day.
# </li>
#
# <li>
# By analyzing this data, we can identify peak visiting hours, busiest days of the week,
# and periods when the emergency room experiences the highest number of patient arrivals.
# </li>
#
# <li>
# The dataset also helps evaluate patient waiting times and determine whether certain factors
# such as age group, triage level, or busy hours influence how long patients wait for treatment.
# </li>
#
# <li>
# Overall, this dataset provides valuable insights that help hospitals understand ER workload patterns
# and make better decisions to improve efficiency and reduce patient waiting time.
# </li>
#
# </ul>
#
# </div>

# %% [markdown]
# <!-- SUBSECTION -->
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Features Overview
# </h3>
#
# <ul style="color:#cfd8dc; line-height:1.9; font-size:16px;">
#
# <li>
# <b style="color:#ffffff;">Patient Arrival Time:</b> Indicates the exact time when a patient arrives at the emergency room.
# </li>
#
# <li>
# <b style="color:#ffffff;">Waiting Time:</b> Represents the duration a patient waits before receiving medical attention.
# </li>
#
# <li>
# <b style="color:#ffffff;">Age:</b> Shows the age of the patient visiting the emergency department.
# </li>
#
# <li>
# <b style="color:#ffffff;">Gender:</b> Identifies whether the patient is male or female.
# </li>
#
# <li>
# <b style="color:#ffffff;">Triage Level:</b> Indicates the priority level assigned to a patient based on the severity of their condition.
# </li>
#
# <li>
# <b style="color:#ffffff;">Day of Visit:</b> Shows the specific day when the patient visited the emergency room.
# </li>
#
# <li>
# <b style="color:#ffffff;">Hour of Arrival:</b> Represents the hour in which the patient arrived, helping identify busy periods.
# </li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# DATA IMPORT & INITIAL CHECK
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Import Libraries
# </h3>
#
# </div>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Load Dataset
# </h3>
#
# </div>

# %%
df=pd.read_csv('./archive/ER Wait Time Dataset.csv')

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Display First Five Rows
# </h3>
#
# </div>

# %%
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region           Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban  2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural  2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural  2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban  2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban  2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Check Dataset Shape
# </h3>
#
# </div>

# %%
df.shape
# Out:
# (5000, 19)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Check Dataset Type
# </h3>
#
# </div>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Visit ID                            5000 non-null   str
#  1   Patient ID                          5000 non-null   str
#  2   Hospital ID                         5000 non-null   str
#  3   Hospital Name                       5000 non-null   str
#  4   Region                              5000 non-null   str
#  5   Visit Date                          5000 non-null   str
#  6   Day of Week                         5000 non-null   str
#  7   Season                              5000 non-null   str
#  8   Time of Day                         5000 non-null   str
#  9   Urgency Level                       5000 non-null   str
#  10  Nurse-to-Patient Ratio              5000 non-null   int64
#  11  Specialist Availability             5000 non-null   int64
# ...

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# DATA CLEANING
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Handling Mising Values
# </h3>
#
# </div>

# %%
df.isnull().sum()
# Out:
# Visit ID                              0
# Patient ID                            0
# Hospital ID                           0
# Hospital Name                         0
# Region                                0
# Visit Date                            0
# Day of Week                           0
# Season                                0
# Time of Day                           0
# Urgency Level                         0
# Nurse-to-Patient Ratio                0
# Specialist Availability               0
# Facility Size (Beds)                  0
# Time to Registration (min)            0
# Time to Triage (min)                  0
# Time to Medical Professional (min)    0
# Total Wait Time (min)                 0
# Patient Outcome                       0
# Patient Satisfaction                  0
# dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Removing Duplicate Record
# </h3>
#
# </div>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Fixing Date &Time Format
# </h3>
#
# </div>

# %%
df['Visit Date']=pd.to_datetime(df['Visit Date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Visit ID                            5000 non-null   str
#  1   Patient ID                          5000 non-null   str
#  2   Hospital ID                         5000 non-null   str
#  3   Hospital Name                       5000 non-null   str
#  4   Region                              5000 non-null   str
#  5   Visit Date                          5000 non-null   datetime64[us]
#  6   Day of Week                         5000 non-null   str
#  7   Season                              5000 non-null   str
#  8   Time of Day                         5000 non-null   str
#  9   Urgency Level                       5000 non-null   str
#  10  Nurse-to-Patient Ratio              5000 non-null   int64
# ...

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Creating Arrival Hours
# </h3>
#
# </div>

# %%
df['Hour of Arrival'] = df['Visit Date'].dt.hour

# %%
df['Hour of Arrival'].head()
# Out:
# 0    20
# 1     2
# 2     4
# 3     0
# 4    16
# Name: Hour of Arrival, dtype: int32

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Create Day of Week
# </h3>
#
# </div>

# %%
df['Day of Week'] = df['Visit Date'].dt.day_name()

# %%
df[['Visit Date','Day of Week']].head()
# Out:
#            Visit Date Day of Week
# 0 2024-02-10 20:20:56    Saturday
# 1 2024-11-28 02:07:47    Thursday
# 2 2024-09-30 04:02:28      Monday
# 3 2024-02-27 00:31:13     Tuesday
# 4 2024-03-06 16:52:26   Wednesday

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">BASIC STATISTICS
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Average Waiting Time
# </h3>
#
# </div>

# %%
df['Total Wait Time (min)'].mean()
# Out:
# np.float64(81.9166)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Median Waiting Time
#
# </h3>
#
# </div>

# %%
df['Total Wait Time (min)'].median()
# Out:
# np.float64(60.0)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Minimum Waiting Time
# </h3>
#
# </div>

# %%
df['Total Wait Time (min)'].min()
# Out:
# np.int64(4)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Maximum Waiting Time
# </h3>
#
# </div>

# %%
df['Total Wait Time (min)'].max()
# Out:
# np.int64(442)

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">PEAK TIME ANALYSIS
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Patient Per Hour
# </h3>
#
# </div>

# %%
patient_per_Hour = df['Hour of Arrival'].value_counts().sort_index()
patient_per_Hour
# Out:
# Hour of Arrival
# 0     228
# 1     218
# 2     194
# 3     171
# 4     182
# 5     219
# 6     213
# 7     206
# 8     221
# 9     215
# 10    231
# 11    228
# 12    197
# 13    212
# 14    213
# 15    199
# 16    219
# 17    181
# 18    205
# 19    217
# 20    205
# 21    227
# 22    213
# 23    186
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Busiest Day
# </h3>
#
# </div>

# %%
busiest_day = df['Day of Week'].value_counts()
print(busiest_day)
# Out:
# Day of Week
# Monday       768
# Tuesday      741
# Sunday       725
# Thursday     706
# Saturday     701
# Friday       685
# Wednesday    674
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Buisiest Month
# </h3>
#
# </div>

# %%
busiest_month = df['Visit Date'].dt.month.value_counts().sort_index()
print("Busiest Month:")
print(busiest_month)
# Out:
# Busiest Month:
# Visit Date
# 1     436
# 2     418
# 3     398
# 4     427
# 5     402
# 6     429
# 7     419
# 8     433
# 9     415
# 10    432
# 11    387
# 12    404
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Most Croweded Time of Day</h3>
#
# </div>

# %%
most_crowed = df['Hour of Arrival'].value_counts().idxmax()
print("most_crowed:" , most_crowed)
# Out:
# most_crowed: 10

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">WAITING TIME ANALYSIS
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Waiting Time Distribution
# </h3>
#
# </div>

# %%
plt.figure(figsize=(12, 5))
plt.hist(df['Total Wait Time (min)'], bins=30, color='#00c6ff', edgecolor='black', alpha=0.7)
plt.xlabel('Total Wait Time (min)', fontsize=12)
plt.ylabel('Number of Patients', fontsize=12)
plt.title('Waiting Time Distribution', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Urgency Level VS Waiting Time
# </h3>
#
# </div>

# %%
triage_wait = df.groupby('Urgency Level')['Total Wait Time (min)'].mean()
triage_wait
# Out:
# Urgency Level
# Critical     18.351047
# High         43.187149
# Low         173.536825
# Medium       93.695585
# Name: Total Wait Time (min), dtype: float64

# %%
plt.figure(figsize=(12, 5))
triage_wait.plot(kind='bar', color=["#b40707","#2a8aeb","#31cc31","#ce8f51"])
plt.xlabel('Urgency Level', fontsize=12)
plt.ylabel('Average Wait Time (min)', fontsize=12)
plt.title('Average Wait Time by Urgency Level', fontsize=14, fontweight='bold')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Waiting Time By Hour
# </h3>
#
# </div>

# %%
hour_wait= df.groupby('Hour of Arrival')['Total Wait Time (min)'].mean()
hour_wait
# Out:
# Hour of Arrival
# 0     82.456140
# 1     72.747706
# 2     84.726804
# 3     84.654971
# 4     82.620879
# 5     82.401826
# 6     80.859155
# 7     77.067961
# 8     89.239819
# 9     90.037209
# 10    75.848485
# 11    81.008772
# 12    84.279188
# 13    83.084906
# 14    80.488263
# 15    75.768844
# 16    78.200913
# 17    83.569061
# 18    79.775610
# 19    82.511521
# 20    86.239024
# 21    89.052863
# 22    80.826291
# 23    79.021505
# Name: Total Wait Time (min), dtype: float64

# %%
plt.figure(figsize=(12, 5))
hour_wait.plot(kind='line', marker='o', color="#ff3392") 
plt.xlabel('Hour of Arrival', fontsize=12)
plt.ylabel('Average Wait Time (min)', fontsize=12)
plt.title('Average Wait Time by Hour of Arrival', fontsize=14, fontweight='bold')
plt.xticks(range(0, 24))
plt.grid()
plt.show()

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">DEMOGRAPHIC STUDY
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Region Wise Patients
# </h3>
#
# </div>

# %%
plt.figure(figsize=(12, 5))
df['Region'].value_counts().plot(kind='bar', color="#ff5e00")
plt.xlabel('Region', fontsize=12, fontweight='bold')
plt.ylabel('Number of Patients', fontsize=12, fontweight='bold')
plt.title('Number of Patients by Region', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Most Common Urgency Level
# </h3>
#
# </div>

# %%
plt.figure(figsize=(12, 5))
df['Urgency Level'].value_counts().plot(kind='bar', color="#00c6ff")
plt.xlabel('Urgency Level',fontsize=12,fontweight='bold')
plt.ylabel('Number of patients', fontsize=12,fontweight='bold')
plt.title('Number of patients by Urgency Level',fontsize=14,fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Patient Outcome Analysis
# </h3>
#
# </div>

# %%
df['Patient Outcome'].value_counts()
# Out:
# Patient Outcome
# Discharged                 2879
# Admitted                   1868
# Left Without Being Seen     253
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 5))
df['Patient Outcome'].value_counts().plot(kind='bar', color="#ff5e00")
plt.xlabel('Patient Outcome', fontsize=12, fontweight='bold')
plt.ylabel('Number of Patients', fontsize=12, fontweight='bold')
plt.title('Number of Patients by Outcome', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Satisfaction Analysis
# </h3>
#
# </div>

# %%
df['Patient Satisfaction'].value_counts()
# Out:
# Patient Satisfaction
# 1    1538
# 4    1429
# 3     873
# 2     605
# 5     555
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 5))
df['Patient Satisfaction'].value_counts().plot(kind='bar', color="#ff5e00")
plt.title(('Patient Satisfaction'),fontweight='bold',fontsize=12)
plt.xlabel('Satisfaction Level', fontsize=12, fontweight='bold')
plt.ylabel('Number of Patients', fontsize=12, fontweight='bold')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">DATA VISUALIZATION
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Patients By Day of Week (bar plot)
# </h3>
#
# </div>

# %%
day_counts = df['Day of Week'].value_counts()
plt.figure(figsize=(12, 5))
day_counts.plot(kind='bar', color="#00c6ff")
plt.xlabel('Day of Week', fontsize=12, fontweight='bold')   
plt.ylabel('Number of Patients', fontsize=12, fontweight='bold')
plt.title('Number of Patients by Day of Week', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="color:#ffffff; font-family:Segoe UI, sans-serif; font-size:16px; font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The bar chart shows the number of patients visiting the emergency department on each day of the week.
# The day with the highest bar represents the busiest day.
# This information helps hospital management plan staffing and resources more effectively.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Patients Outcomes (pie plot)
# </h3>
#
# </div>

# %%
df['Patient Outcome'].value_counts().plot(kind='pie', autopct='%1.1f%%',colors=["#ff5e00", "#00c6ff", "#31cc31", "#ce8f51"] )
plt.title('Patient Outcome Distribution', fontsize=14, fontweight='bold')
plt.axis('equal')
plt.figure(figsize=(12, 5))
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
# padding:20px;
# border-radius:12px;
# border:1px solid #00c6ff;
# margin-top:15px;">
#
# <p style="color:#ffffff;font-size:16px;font-weight:700;">Conclusion:</p>
#
# <p style="color:#cfd8dc;line-height:1.8;font-size:15px;">
# The pie chart represents the proportion of different patient outcomes such as discharge or admission.
# A higher discharge percentage suggests that many cases are treated successfully without hospitalization.
# This helps evaluate hospital treatment efficiency.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Total Wait Time (histogram)
# </h3>
#
# </div>

# %%
plt.figure(figsize=(12, 5))
df['Total Wait Time (min)'].value_counts().plot(kind='hist', bins=30, color='#00c6ff', edgecolor='black', alpha=0.7)
plt.xlabel('Total Wait Time (min)', fontsize=12, fontweight='bold')
plt.ylabel('Number of Patients', fontweight='bold', fontsize=12)
plt.title('Total Wait Time Distribution', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
# padding:20px;
# border-radius:12px;
# border:1px solid #00c6ff;
# margin-top:15px;">
#
# <p style="color:#ffffff;font-size:16px;font-weight:700;">Conclusion:</p>
#
# <p style="color:#cfd8dc;line-height:1.8;font-size:15px;">
# The histogram shows how waiting times are distributed among patients.
# Most patients appear to wait within a moderate time range.
# A few long waiting times may indicate peak hospital congestion.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# Hour Of Arrival (line chart)
# </h3>
#
# </div>

# %%
hour_counts = df['Hour of Arrival'].value_counts().sort_index()
plt.figure(figsize=(12, 5))
hour_counts.plot(kind='line',marker='o', color="#ff3392")
plt.xlabel('Hour of Arrival', fontsize=12, fontweight='bold')
plt.ylabel('Number of Patients', fontsize=12, fontweight='bold')
plt.title('Number of Patients by Hour of Arrival', fontsize=14, fontweight='bold')
plt.xticks(rotation=0)
plt.grid()
plt.xticks(range(0, 24))
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
# padding:20px;
# border-radius:12px;
# border:1px solid #00c6ff;
# margin-top:15px;">
#
# <p style="color:#ffffff;font-size:16px;font-weight:700;">Conclusion:</p>
#
# <p style="color:#cfd8dc;line-height:1.8;font-size:15px;">
# The line chart shows how patient arrivals change throughout the day.
# Certain hours have higher peaks indicating busy periods.
# Hospitals can use this insight to improve scheduling of staff.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Time To Medical Professional (box plot)
# </h3>
#
# </div>

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(y=df['Time to Medical Professional (min)'])
plt.title('Time to Medical Professional Distribution', fontsize=14, fontweight='bold')
plt.ylabel('Time to Medical Professional (min)', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
# padding:20px;
# border-radius:12px;
# border:1px solid #00c6ff;
# margin-top:15px;">
#
# <p style="color:#ffffff;font-size:16px;font-weight:700;">Conclusion:</p>
#
# <p style="color:#cfd8dc;line-height:1.8;font-size:15px;">
# This box plot shows variation in time taken for patients to see a medical professional.
# Outliers may represent unusually long delays.
# Reducing this time improves emergency department performance.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Wait Time VS Registration Time (scatter plot)
# </h3>
#
# </div>

# %%
plt.figure(figsize=(12, 5))
plt.scatter(df[['Time to Registration (min)']], df['Total Wait Time (min)'], alpha=0.5, color="#00c6ff")
plt.xlabel('Time to Registration (min)', fontsize=12, fontweight='bold')
plt.ylabel('Total Wait Time')
plt.title('Total Wait Time vs Time to Registration', fontsize=14, fontweight='bold')
plt.grid()
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
# padding:20px;
# border-radius:12px;
# border:1px solid #00c6ff;
# margin-top:15px;">
#
# <p style="color:#ffffff;font-size:16px;font-weight:700;">Conclusion:</p>
#
# <p style="color:#cfd8dc;line-height:1.8;font-size:15px;">
# The scatter plot explores the relationship between registration time and total waiting time.
# A positive pattern suggests that delays during registration can increase overall waiting time.
# Improving registration efficiency may reduce patient waiting times.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
#     Correlation of Time Variable
# </h3>
#
# </div>

# %%
corr = df[['Time to Registration (min)',
           'Time to Triage (min)',
           'Time to Medical Professional (min)',
           'Total Wait Time (min)']].corr()

plt.figure()
sns.heatmap(corr, annot=True)
plt.title("Correlation Between Time Variables")
plt.xticks(rotation=45)
plt.show()
